# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import glob
from PIL import Image
import cv2
from settings import *
from scripts import *
import theano

# %%
file_list = glob.glob(image_dir + '*')

# %%
img = cv2.imread(test_dir + 'lena.png')
img = np.float64(img)
X_lcn = lecun_lcn(img, threshold=1e-4, radius=15)
img_lcn = X_lcn.eval()
img_lcn = np.array(img_lcn)[0]
img_lcn_rgb = np.array([img_lcn[0], img_lcn[2], img_lcn[1]])
img_lcn_rgb.shape
img_lcn_rgb = img_lcn_rgb.transpose(1, 2, 0)
plt.imshow(img_lcn_rgb)

# %%
img = cv2.imread(file_list[0])
img = cv2.cvtColor(img, cv2.COLOR_BGR2YCR_CB)
laplist = laplacian_pyramid(img, 3)
plt.imshow(cv2.cvtColor(laplist[0], cv2.COLOR_YCR_CB2RGB))

# %%
img = cv2.imread(file_list[0])
laplist = laplacian_pyramid(img, 3)
plt.imshow(cv2.cvtColor(laplist[0], cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread(file_list[0])
img = np.float64(img)
img.dtype
img_lcn = lecun_lcn(img, threshold=1e-4, radius=15)
img_lcn = img_lcn[0].transpose(1, 2, 0)
plt.imshow(cv2.cvtColor(laplist[0], cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('./lena.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
